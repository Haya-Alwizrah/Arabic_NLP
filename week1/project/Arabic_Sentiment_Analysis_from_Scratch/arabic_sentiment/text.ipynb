# %%
import re
from preprocessing import ArabicPreprocessor

# %%
p = ArabicPreprocessor()

# %%
text = """
السَلااام عَليكممم ورحمههه اللّه وبركاتٌهههه

#https:\\google.com
أحمد أكل التفاحة
😭☹️👋🏻👋🎨🤣😂✨🔟👑
#كلنا_واحد
@hayush_idv
/.,,/؟.,’/:ـ:
"""

# %%
result = p.preprocess(text, False)

# %%
result
# Out:
# 'السلاام عليكمم ورحمهه الله وبركاتهه احمد اكل التفاحه كلنا واحد ـ'

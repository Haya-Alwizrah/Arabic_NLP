# %%
import re
from preprocessing import ArabicPreprocessor

# %%
p = ArabicPreprocessor()

text = """
السلااام عليكممم ورحمههه الله وبركاتهههه

أحمد أكل التفاحة
😭☹️👋🏻👋🎨🤣😂✨🔟👑
#كلنا_واحد
@hayush_idv
/.,,/؟.,’/:ـ:
"""

result = p.preprocess(text)

print(result)
# Out:
# ['السلام', 'عليكم', 'ورحمه', 'اله', 'وبركاتهاحمد', 'اكل', 'التفاحهكلناواحدـ']

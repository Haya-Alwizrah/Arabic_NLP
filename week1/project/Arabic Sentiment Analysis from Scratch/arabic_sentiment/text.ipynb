# %%
import re
from preprocessing import preprocess
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 import re
# ----> 2 from preprocessing import preprocess
#
# ImportError: cannot import name 'preprocess' from 'preprocessing' (c:\Users\computer\Documents\GitHub\Arabic_NLP\week1\project\Arabic Sentiment Analysis from Scratch\arabic_sentiment\preprocessing.py)

# %%
text = """
السلااام عليكممم ورحمههه الله وبركاتهههه

أحمد أكل التفاحة
😭☹️👋🏻👋🎨🤣😂✨🔟👑
#كلنا_واحد
@hayush_idv
/.,,/؟.,’/:ـ:
"""

# %%
p = preprocess()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p = preprocess()
#
# NameError: name 'preprocess' is not defined

# %%
# Out:
# ' سلام عليكم مرحبا\n'

# %%
text = "مفعول"

# %%
def wazen(text):
    match text:
        case text[1] == "م" and text[3] == "و":
                print("مفعول")
# Out:
#   Cell In[4], line 3
#     case text[:1] == "م" and text[3] == "و":
#              ^
# SyntaxError: invalid syntax

# %%
wazen("مشروب")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 wazen("مشروب")
#
# NameError: name 'wazen' is not defined
